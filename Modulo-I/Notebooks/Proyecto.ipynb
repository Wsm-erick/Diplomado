# %% [markdown]
# https://archive.ics.uci.edu/dataset/320/student%2Bperformance?utm_source=chatgpt.com

# %% [markdown]
# https://archive.ics.uci.edu/dataset/697/predict%2Bstudents%2Bdropout%2Band%2Bacademic%2Bsuccess?utm_source=chatgpt.com

# %% [markdown]
# https://data.mendeley.com/datasets/4mvgvtxc8s/1

# %%
import pandas as pd

# %%
pd.read_csv(r'https://raw.githubusercontent.com/Wsm-erick/Diplomado/refs/heads/main/Modulo-I/Datasets/student_dataset.csv')
# Out:
#           Student_Names   Phone_No.  Math  Physics  Chemistry Grade  \
# 0      Donald Contreras  9208625450    76       84         54    B+
# 1         Joseph Horton  9886408555    91       75         78     A
# 2     Savannah Burns MD  9047592659    64       98         20     C
# 3        William Carter  9048473864    15       95         32     D
# 4        John Rodriguez  9685225730    86       86         66    B+
# ...                 ...         ...   ...      ...        ...   ...
# 8995   Kimberly Stevens  9129352703    40       87         65     B
# 8996     Kelsey Bonilla  9649715711    56       84         75    B+
# 8997         Kelly Dunn  9825362271    80       70         16     C
# 8998     Joseph Nichols  9363540473    24       95         59     C
# 8999    Susan Armstrong  9879539785    31       76         18     D
#
#                        Comment  Roll No.           School Name  \
# 0               Good Pursuance    524613  Martin Luther School
# 1         Very Good Achivement    561635  Martin Luther School
# 2     Below Average Achivement    560985  Martin Luther School
# 3               Poor Pursuance    535126  Martin Luther School
# 4               Good Pursuance    559410  Martin Luther School
# ...                        ...       ...                   ...
# 8995       Average Performance    569342  Martin Luther School
# 8996            Good Pursuance    530124  Martin Luther School
# 8997  Below Average Achivement    592266  Martin Luther School
# 8998  Below Average Achivement    583028  Martin Luther School
# 8999            Poor Pursuance    503637  Martin Luther School
#
#                                         Student Address
# 0                478 Mooney Park, New Valerie, VI 28836
# 1               037 Matthew Shores, Greeneton, CA 98399
# 2            96124 Lloyd Streets, Edwardmouth, DC 61677
# 3               11959 Clark Village, Ivanview, NH 43940
# 4     051 Weaver Glen Apt. 724, West Davidborough, M...
# ...                                                 ...
# 8995          27054 Adrian Streets, Diazmouth, OH 81346
# 8996        570 Christopher Run, Williammouth, ND 11535
# 8997   32283 Carpenter Summit, North Patricia, PR 51483
# 8998  2336 Blackburn Fall Apt. 905, South Shelby, ND...
# 8999      2328 Jennifer Extension, Lake David, OR 11243
#
# [9000 rows x 10 columns]

# %%
pd.read_csv(r'https://raw.githubusercontent.com/Wsm-erick/Diplomado/refs/heads/main/Modulo-I/Datasets/predict_dropout.csv', sep=';')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# 1                                1                       1
# 2                                1                       1
# 3                                1                       1
# 4                                0                       1
# ...                            ...                     ...
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                              122.0            1                      19
# 1                              160.0            1                       1
# 2                              122.0            1                      37
# 3                              122.0            1                      38
# 4                              100.0            1                      37
# ...                              ...          ...                     ...
# 4419                           125.0            1                       1
# 4420                           120.0          105                       1
# 4421                           154.0            1                      37
# 4422                           180.0            1                      37
# 4423                           152.0           22                      38
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                         12  ...                                    0
# 1                          3  ...                                    0
# 2                         37  ...                                    0
# 3                         37  ...                                    0
# 4                         38  ...                                    0
# ...                      ...  ...                                  ...
# 4419                       1  ...                                    0
# 4420                       1  ...                                    0
# 4421                      37  ...                                    0
# 4422                      37  ...                                    0
# 4423                      37  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       6
# 3                                       6
# 4                                       6
# ...                                   ...
# 4419                                    6
# 4420                                    6
# 4421                                    8
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                          6
# 2                                          0
# 3                                         10
# 4                                          6
# ...                                      ...
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         13.666667
# 2                                       0                          0.000000
# 3                                       5                         12.400000
# 4                                       6                         13.000000
# ...                                   ...                               ...
# 4419                                    5                         12.666667
# 4420                                    2                         11.000000
# 4421                                    1                         13.500000
# 4422                                    5                         12.000000
# 4423                                    6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                                  0               10.8
# 1                                                  0               13.9
# 2                                                  0               10.8
# 3                                                  0                9.4
# 4                                                  0               13.9
# ...                                              ...                ...
# 4419                                               0               15.5
# 4420                                               0               11.1
# 4421                                               0               13.9
# 4422                                               0                9.4
# 4423                                               0               12.7
#
#       Inflation rate   GDP    Target
# 0                1.4  1.74   Dropout
# 1               -0.3  0.79  Graduate
# 2                1.4  1.74   Dropout
# 3               -0.8 -3.12  Graduate
# 4               -0.3  0.79  Graduate
# ...              ...   ...       ...
# 4419             2.8 -4.06  Graduate
# 4420             0.6  2.02   Dropout
# 4421            -0.3  0.79   Dropout
# 4422            -0.8 -3.12  Graduate
# 4423             3.7 -1.70  Graduate
#
# [4424 rows x 37 columns]

# %%
pd.read_csv(r'https://raw.githubusercontent.com/Wsm-erick/Diplomado/refs/heads/main/Modulo-I/Datasets/var_predict_dropout.csv')
# Out:
#                                  Variable Original  \
# 0                                   Marital status
# 1                                 Application mode
# 2                                Application order
# 3                                           Course
# 4                       Daytime/evening attendance
# 5                           Previous qualification
# 6                   Previous qualification (grade)
# 7                                      Nacionality
# 8                           Mother's qualification
# 9                           Father's qualification
# 10                             Mother's occupation
# 11                             Father's occupation
# 12                                 Admission grade
# 13                                       Displaced
# 14                       Educational special needs
# 15                                          Debtor
# 16                         Tuition fees up to date
# 17                                          Gender
# 18                              Scholarship holder
# 19                               Age at enrollment
# 20                                   International
# 21             Curricular units 1st sem (credited)
# 22             Curricular units 1st sem (enrolled)
# 23          Curricular units 1st sem (evaluations)
# 24             Curricular units 1st sem (approved)
# 25                Curricular units 1st sem (grade)
# 26  Curricular units 1st sem (without evaluations)
# 27             Curricular units 2nd sem (credited)
# 28             Curricular units 2nd sem (enrolled)
# 29          Curricular units 2nd sem (evaluations)
# 30             Curricular units 2nd sem (approved)
# 31                Curricular units 2nd sem (grade)
# 32  Curricular units 2nd sem (without evaluations)
# 33                               Unemployment rate
# 34                                  Inflation rate
# 35                                             GDP
# 36                                          Target
#
#                             Variable en Español  \
# 0                                  Estado civil
# 1                            Modo de aplicación
# 2                           Orden de aplicación
# 3                                         Curso
# 4                    Asistencia diurna/nocturna
# 5                   Calificación previa (nivel)
# 6                    Calificación previa (nota)
# 7                                  Nacionalidad
# 8                   Nivel educativo de la madre
# 9                     Nivel educativo del padre
# 10                        Ocupación de la madre
# 11                          Ocupación del padre
# 12                             Nota de admisión
# 13                                   Desplazado
# 14            Necesidades educativas especiales
# 15                                       Deudor
# 16                          Cuotas al corriente
# 17                                       Género
# 18                                      Becario
# 19                          Edad al inscribirse
# 20                                Internacional
# 21     Unid. curriculares 1er sem (acreditadas)
# 22       Unid. curriculares 1er sem (inscritas)
# 23    Unid. curriculares 1er sem (evaluaciones)
# 24       Unid. curriculares 1er sem (aprobadas)
# 25                        Promedio 1er semestre
# 26  Unid. curriculares 1er sem (sin evaluación)
# 27     Unid. curriculares 2do sem (acreditadas)
# 28       Unid. curriculares 2do sem (inscritas)
# 29    Unid. curriculares 2do sem (evaluaciones)
# 30       Unid. curriculares 2do sem (aprobadas)
# 31                         Promedio 2º semestre
# 32  Unid. curriculares 2do sem (sin evaluación)
# 33                            Tasa de desempleo
# 34                            Tasa de inflación
# 35                                          PIB
# 36                                     Objetivo
#
#                                      Descripción (ES)
# 0   1 – soltero, 2 – casado, 3 – viudo, 4 – divorc...
# 1   Canal o contingente de ingreso (p. ej., 1ª fas...
# 2   Preferencia de la solicitud (0 = primera opció...
# 3               Código del programa/curso matriculado
# 4                            1 = diurna, 0 = nocturna
# 5   Nivel educativo previo (secundaria, licenciatu...
# 6      Nota de la calificación previa (entre 0 y 200)
# 7   Código de nacionalidad (p. ej., 1 portugués, 4...
# 8   Nivel de estudios de la madre (secundaria, sup...
# 9   Nivel de estudios del padre (secundaria, super...
# 10                  Categoría ocupacional de la madre
# 11                    Categoría ocupacional del padre
# 12           Nota de ingreso a la institución (0–200)
# 13  Estudiante desplazado de su residencia habitua...
# 14  Indicador de necesidades educativas especiales...
# 15     Estudiante con deudas registradas (1 sí, 0 no)
# 16            Pago de colegiatura al día (1 sí, 0 no)
# 17                        1 = masculino, 0 = femenino
# 18                  Beneficiario de beca (1 sí, 0 no)
# 19   Edad del estudiante al momento de la inscripción
# 20                                         1 sí, 0 no
# 21  Número de unidades curriculares acreditadas en...
# 22  Número de unidades curriculares inscritas en e...
# 23  Número de evaluaciones realizadas en el 1er se...
# 24  Número de unidades curriculares aprobadas en e...
# 25        Promedio de notas en el 1er semestre (0–20)
# 26  Número de unidades curriculares sin evaluación...
# 27  Número de unidades curriculares acreditadas en...
# 28  Número de unidades curriculares inscritas en e...
# 29  Número de evaluaciones realizadas en el 2º sem...
# 30  Número de unidades curriculares aprobadas en e...
# 31         Promedio de notas en el 2º semestre (0–20)
# 32  Número de unidades curriculares sin evaluación...
# 33                      Tasa de desempleo del periodo
# 34                      Tasa de inflación del periodo
# 35  Producto Interno Bruto (indicador macroeconómico)
# 36  Estado al final del curso: Dropout / Enrolled ...

# %%
import pandas as pd
import numpy as np

# Modelado
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# Métricas
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# 1) Carga
df = pd.read_csv("data.csv")

# 2) Separar X, y
# Ajusta el nombre exacto si tu CSV difiere (algunas versiones usan 'Target' o 'Status')
target_col = "Target"
X = df.drop(columns=[target_col])
y = df[target_col].astype("category")

# 3) Detectar tipos (puedes hacer una lista manual si prefieres control total)
# Regla: numéricas = int/float; categóricas = object/category/bool
num_cols = X.select_dtypes(include=["int64", "float64", "int32", "float32"]).columns.tolist()
cat_cols = X.select_dtypes(include=["object", "category", "bool"]).columns.tolist()

# (Opcional) si algunas columnas codificadas 0/1 realmente son categóricas ordinales, puedes moverlas manualmente a num_cols/cat_cols

# Transformador de columnas: one-hot a categóricas; escalado SOLO a numéricas
preprocess = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), cat_cols),
    ],
    remainder="drop",
)

# 4) train/test estratificado (mantener proporción de clases)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# 5) Definir tres pipelines (evita fuga de datos al hacer el escalado dentro del pipeline)
pipe_knn = Pipeline(steps=[
    ("prep", preprocess),
    ("clf", KNeighborsClassifier())
])

pipe_log = Pipeline(steps=[
    ("prep", preprocess),
    ("clf", LogisticRegression(max_iter=2000, multi_class="multinomial", n_jobs=None))
])

pipe_tree = Pipeline(steps=[
    ("prep", preprocess),
    ("clf", DecisionTreeClassifier(random_state=42))
])

# 6) Entrenar y evaluar función helper
def evaluar(modelo, nombre):
    modelo.fit(X_train, y_train)
    y_pred = modelo.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    f1m = f1_score(y_test, y_pred, average="macro")
    print(f"\n=== {nombre} ===")
    print(f"Accuracy: {acc:.4f} | F1-macro: {f1m:.4f}")
    print(classification_report(y_test, y_pred))
    print("Matriz de confusión:")
    print(confusion_matrix(y_test, y_pred, labels=y.cat.categories))

evaluar(pipe_knn, "KNN (k=5 por defecto)")
evaluar(pipe_log, "Regresión Logística (multinomial)")
evaluar(pipe_tree, "Árbol de Decisión")

# 7) GridSearch para KNN (elige k óptimo)
param_grid_knn = {
    "clf__n_neighbors": [3,5,7,9,11,13,15],
    "clf__weights": ["uniform", "distance"],
    "clf__p": [1, 2],  # 1=Manhattan, 2=Euclidiana
}
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid_knn = GridSearchCV(pipe_knn, param_grid_knn, scoring="f1_macro", cv=cv, n_jobs=-1)
grid_knn.fit(X_train, y_train)

print("\nMejor KNN:", grid_knn.best_params_, "→ F1-macro CV:", grid_knn.best_score_)
# Evaluación final con el mejor KNN en test
y_pred_best = grid_knn.best_estimator_.predict(X_test)
print("\n=== KNN (mejor estimador) ===")
print(f"Accuracy: {accuracy_score(y_test, y_pred_best):.4f} | F1-macro: {f1_score(y_test, y_pred_best, average='macro'):.4f}")
print(classification_report(y_test, y_pred_best))
print("Matriz de confusión:")
print(confusion_matrix(y_test, y_pred_best, labels=y.cat.categories))
